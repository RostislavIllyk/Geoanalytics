# %% [markdown]
# <h2 align="center" style="color:Black"> Геоаналитика </h2>

# %% [markdown]
# #### Данное решение является модификацией решения предоставленного участником <b>Evgeny Kazenov</b>.

# %% [markdown]
# <b>Решение:</b>
#
#
#
#
#
# 1. Получаем матрицу признаков на активности клиентов в локациях (основное отличие от оригинала здесь. В оригинальном решении на пересечении пользователь-место ставится статистика активности или -1. В моем решении если пересечения не произошло то я пошагово поднимаюсь на менее точный уровень детализации и если пересечение произошло то ставлю число пропорциональное точности. Если пересечения нет то иду дальше к еще менее точным уровням.)
# 2. Используем кросс валидацию <b>MultilabelStratifiedKFold</b>
# 3. Для загрузки решения обучаем и сохраняем 7 моделей <b>XGBClassifier</b>
# 4. Валидация <b>8.788</b>, Паблик <b>8,8686166</b>

# %% [markdown]
# <b>Замечание:</b>
# Для получения конечных ячеек были опробованы пакеты: <b>h3, geohash, s2cell</b>
# В итоге остановился на <b>s2cell</b>

# %%
from pathlib import Path
import pandas as pd
import h3
import numpy as np
from tqdm import tqdm
#import json
import joblib
from typing import List
from xgboost import XGBClassifier
from statistics import mean
import warnings
warnings.filterwarnings('ignore')
#import geohash
#import geohash_base as gb
from multiprocessing import Pool
import time
import s2cell

# %%
# метрика контеста
def mean_binary_cross_entropy(predictuion, target):
    eps = 1e-8
    mbce = (-np.log(np.clip(predictuion, eps, 1 - eps)) * target \
           - np.log(np.clip(1 - predictuion, eps, 1 - eps)) * (1 - target)).sum(axis=1).mean()
    return mbce

# %%
data_root = ''
hexses_target_path = '../data/hexses_target.lst'
hexses_data_path = '../data/hexses_data.lst'

train_data_fn   = '../data/transactions.parquet'
train_target_fn =  '../data/target.parquet'

# %%
with open(hexses_target_path, "r") as f:
    hexses_target = [x.strip() for x in f.readlines()]

# %%
with open(hexses_data_path, "r") as f:
    hexses_data = [x.strip() for x in f.readlines()]

# %%
transactions = pd.read_parquet(train_data_fn)

# %%
all_possible_hexses = list(set(hexses_data + hexses_target))
len(all_possible_hexses), len(hexses_data), len(hexses_target)
# Out:
# (8157, 8154, 1657)

# %%
# %%time
hexses_dic = {}

for hexs_base in tqdm(all_possible_hexses):
    h_levels = []
    for precision in range(15,6,-1):
        lat, lng = h3.h3_to_geo(hexs_base)
        #hexs = h3.geo_to_h3(lat, lng, precision)
        hexs = s2cell.lat_lon_to_cell_id(lat, lng, precision)
        h_levels.append(hexs)
    hexses_dic[hexs_base] = h_levels
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 8157/8157 [00:00<00:00, 16766.34it/s]
# CPU times: user 490 ms, sys: 748 µs, total: 491 ms
# Wall time: 490 ms

# %%
len(hexses_dic['8911aa7a177ffff'])
# Out:
# 9

# %%
#for i in range(len(hexses_dic['8911aa7a177ffff'])):
print(len(hexses_dic['8911aa7a177ffff']))
# Out:
# 9

# %%
hexses_dic['8911aa7a177ffff'][0]
# Out:
# 5095061855404032000

# %%
joblib.dump(hexses_dic, f'hexses_dic.pkl')
# Out:
# ['hexses_dic.pkl']

# %%
hexses_dic['8911aa7a177ffff']
# Out:
# [5095061855404032000,
#  5095061854330290176,
#  5095061858625257472,
#  5095061910164865024,
#  5095061841445388288,
#  5095061016811667456,
#  5095062116323295232,
#  5095066514369806336,
#  5095048922183761920]

# %%
transactions.head()
# Out:
#              h3_09  customer_id  datetime_id  count       sum       avg  \
# 0  8911aa4c62fffff            1            3      1   3346.65  3346.650
# 1  8911aa7b5b3ffff            4            3      1    450.00   450.000
# 2  8911aa63623ffff            5            3     10  11035.69  1103.569
# 3  8911aa48577ffff            9            2      2    628.00   314.000
# 4  8911aa78297ffff           11            2      1   4155.00  4155.000
#
#        min      max          std  count_distinct  mcc_code
# 0  3346.65  3346.65          NaN               1        13
# 1   450.00   450.00          NaN               1         8
# 2    59.00  3620.18  1190.530333               6        13
# 3   295.00   333.00    26.870058               2         5
# 4  4155.00  4155.00          NaN               1        10

# %%
target = pd.read_parquet(train_target_fn)
target
# Out:
#                   h3_09  customer_id
# 0       8911aa6ac3bffff        23172
# 1       8911aa7a857ffff        95640
# 2       8911aa70b97ffff        60350
# 3       8911aa70b97ffff        69521
# 4       891181b69abffff        29437
# ...                 ...          ...
# 157801  8911aa61cc7ffff        73888
# 157802  8911aa4ecafffff        81775
# 157803  8911aa4ecafffff        38508
# 157804  8911aa63657ffff        14794
# 157805  8911aa7adabffff        17123
#
# [157806 rows x 2 columns]

# %%
target = (
    pd.read_parquet(train_target_fn)
    .assign(customer_id = lambda x: x.customer_id.astype(int))
    .pipe(lambda x: pd.pivot(x.assign(v = 1.), index='customer_id', columns='h3_09', values='v'))
    .pipe(lambda x: x.reindex(sorted(x.columns), axis=1)) # Сортируем столбцы по порядку
    .sort_values(by='customer_id') # сортируем строки
    .fillna(0)
)
target.shape
# Out:
# (69337, 1657)

# %%
def comb_F(n_entry): # the argument n is the number of items to select        
    global dump_list, hexses_data, hexses_dic

    
    item = dump_list[n_entry]
    customer_id, data = item[0], item[1]
    
    user_locations = data.h3_09.tolist()
    loc_feature =[]
    

    user_hash_list_1 = []
    user_hash_list_2 = []
    user_hash_list_3 = []
    user_hash_list_4 = []
    user_hash_list_5 = []
    user_hash_list_6 = []
    user_hash_list_7 = []    
    user_hash_list_8 = []    
    user_hash_list_9 = []
    
    for user_loc in user_locations:
        user_hash_list_1.append(hexses_dic[user_loc][0])
        user_hash_list_2.append(hexses_dic[user_loc][1])
        user_hash_list_3.append(hexses_dic[user_loc][2])
        user_hash_list_4.append(hexses_dic[user_loc][3])
        user_hash_list_5.append(hexses_dic[user_loc][4])
        user_hash_list_6.append(hexses_dic[user_loc][5])
        user_hash_list_7.append(hexses_dic[user_loc][6])
        user_hash_list_8.append(hexses_dic[user_loc][7])
        user_hash_list_9.append(hexses_dic[user_loc][8])
    
    
    for bank_loc in hexses_data:
        
        if bank_loc in user_locations:
            loc_count = data[data.h3_09==bank_loc]['count'].sum()# суммируем все активности в локации
            loc_feature.append(loc_count)    
        else:

            bank_hash = hexses_dic[bank_loc][0]
            if bank_hash in user_hash_list_1:                            
                loc_feature.append(0.9)
            else:                   

                bank_hash = hexses_dic[bank_loc][1]
                if bank_hash in user_hash_list_2:                            
                    loc_feature.append(0.8)
                else:                

                    bank_hash = hexses_dic[bank_loc][2]
                    if bank_hash in user_hash_list_3:                            
                        loc_feature.append(0.7)
                    else:    
                        
                        bank_hash = hexses_dic[bank_loc][3]
                        if bank_hash in user_hash_list_4:                            
                            loc_feature.append(0.6)
                        else:

                            bank_hash = hexses_dic[bank_loc][4]
                            if bank_hash in user_hash_list_5:                            
                                loc_feature.append(0.5)
                                
                            else:  

                                bank_hash = hexses_dic[bank_loc][5]
                                if bank_hash in user_hash_list_6:                            
                                    loc_feature.append(0.4) 
                                else:  

                                    bank_hash = hexses_dic[bank_loc][6]
                                    if bank_hash in user_hash_list_7:                            
                                        loc_feature.append(0.3) 
                                    else:  
    
                                        bank_hash = hexses_dic[bank_loc][7]
                                        if bank_hash in user_hash_list_8:                            
                                            loc_feature.append(0.2) 
                                        else:  
            
                                            bank_hash = hexses_dic[bank_loc][8]
                                            if bank_hash in user_hash_list_9:                            
                                                loc_feature.append(0.1) 
                                            else:                                     
                                                loc_feature.append(-1)
                                    

        string_prep = [customer_id]+loc_feature
    return string_prep

# %%
def count_transform(df,  
                    hexses_data,
                    hexses_dic,
                   ):

    global dump_list
    
    """
    Создание матрицы признаков на активности в каждой локации если активности нет заполняется -1

    """
    
    data_features = []
    dump = df.groupby("customer_id")
    dump_list = list(dump)
    POOLS_NUM = 18




    for customer_id, data in tqdm(dump):
        loc_text = []                   
        for i in range(len(hexses_data)):
            loc  = hexses_data[i]
            loc_text.append(loc+'_count')

            
    col_names = ['customer_id']+loc_text




    p = Pool(POOLS_NUM)
    
    
    
    
    end = len(dump_list)
    n_entry = range(end)    
    #n_entry = range(10000)
    train_data = p.map(comb_F, n_entry) # pass the range as the sequence of arguments!
    p.close()
    p.join()


    train_data = pd.DataFrame(train_data, columns = col_names)
    train_data = train_data.sort_values(by=['customer_id'], ascending=True)

    return train_data

# %%
# %%time
try:
    train_data = joblib.load(f'train_data_S2.pkl')
except: 
    train_data = count_transform(transactions,
                                    hexses_data,
                                    hexses_dic
                            )
    joblib.dump(train_data, f'train_data_S2.pkl')
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 69337/69337 [00:48<00:00, 1428.41it/s]
# CPU times: user 4min 41s, sys: 19.9 s, total: 5min 1s
# Wall time: 25min 54s

# %% [raw]
# %%time
# train_data = count_transform(transactions,
#                                   hexses_data,
#                                   hexses_dic
#                                  )

# %%
len(train_data)
# Out:
# 69337

# %%
train_data
# Out:
#        customer_id  89118180927ffff_count  89118180d27ffff_count  \
# 0                1                    0.2                    0.2
# 1                4                   -1.0                   -1.0
# 2                5                   -1.0                   -1.0
# 3                9                    0.2                    0.2
# 4               11                   -1.0                   -1.0
# ...            ...                    ...                    ...
# 69332        98388                   -1.0                   -1.0
# 69333        98397                   -1.0                   -1.0
# 69334        98409                   -1.0                   -1.0
# 69335        98432                    0.2                    0.2
# 69336        98450                   -1.0                   -1.0
#
#        891181820abffff_count  891181840a7ffff_count  891181844c3ffff_count  \
# 0                        0.2                    0.3                    0.3
# 1                       -1.0                   -1.0                   -1.0
# 2                       -1.0                   -1.0                   -1.0
# 3                        0.2                    0.3                    0.3
# 4                       -1.0                   -1.0                   -1.0
# ...                      ...                    ...                    ...
# 69332                   -1.0                   -1.0                   -1.0
# 69333                   -1.0                   -1.0                   -1.0
# 69334                   -1.0                   -1.0                   -1.0
# 69335                    0.2                    0.3                    0.3
# 69336                   -1.0                   -1.0                   -1.0
#
#        89118184c93ffff_count  891181854b7ffff_count  89118186067ffff_count  \
# 0                        0.3                    0.2                    0.3
# 1                       -1.0                   -1.0                   -1.0
# 2                       -1.0                   -1.0                   -1.0
# 3                        0.3                    0.2                    0.3
# 4                       -1.0                   -1.0                   -1.0
# ...                      ...                    ...                    ...
# 69332                   -1.0                   -1.0                   -1.0
# 69333                   -1.0                   -1.0                   -1.0
# 69334                   -1.0                   -1.0                   -1.0
# 69335                    0.4                    0.2                    0.3
# 69336                   -1.0                   -1.0                   -1.0
#
#        8911818610bffff_count  ...  8911aa7b6b3ffff_count  \
# 0                        0.3  ...                    0.7
# 1                       -1.0  ...                    0.7
# 2                       -1.0  ...                    0.3
# 3                        0.3  ...                    0.4
# 4                       -1.0  ...                    0.7
# ...                      ...  ...                    ...
# 69332                   -1.0  ...                    0.4
# 69333                   -1.0  ...                    0.4
# 69334                   -1.0  ...                    0.3
# 69335                    0.3  ...                    0.3
# 69336                   -1.0  ...                    0.4
#
#        8911aa7b6bbffff_count  8911aa7b6c3ffff_count  8911aa7b6c7ffff_count  \
# 0                        0.7                    0.5                    0.5
# 1                        0.7                    0.5                    0.5
# 2                        0.3                    0.3                    0.3
# 3                        0.4                    0.4                    0.4
# 4                        0.7                    0.5                    0.5
# ...                      ...                    ...                    ...
# 69332                    0.4                    0.4                    0.4
# 69333                    0.4                    0.4                    0.4
# 69334                    0.3                    0.3                    0.3
# 69335                    0.3                    0.3                    0.3
# 69336                    0.4                    0.4                    0.4
#
#        8911aa7b6cbffff_count  8911aa7b6cfffff_count  8911aa7b6d3ffff_count  \
# 0                        0.5                    0.5                    0.5
# 1                        0.5                    0.5                    0.5
# 2                        0.3                    0.3                    0.3
# 3                        0.4                    0.4                    0.4
# 4                        0.5                    0.5                    0.5
# ...                      ...                    ...                    ...
# 69332                    0.4                    0.4                    0.4
# 69333                    0.4                    0.4                    0.4
# 69334                    0.3                    0.3                    0.3
# 69335                    0.3                    0.3                    0.3
# 69336                    0.4                    0.4                    0.4
#
#        8911aa7b6d7ffff_count  8911aa7b6dbffff_count  8911aaccacfffff_count
# 0                        0.5                    0.5                    0.2
# 1                        0.5                    0.5                    0.2
# 2                        0.3                    0.3                    0.2
# 3                        0.4                    0.4                    0.2
# 4                        0.5                    0.5                    0.2
# ...                      ...                    ...                    ...
# 69332                    0.4                    0.4                    0.2
# 69333                    0.4                    0.4                    0.2
# 69334                    0.3                    0.3                    0.2
# 69335                    0.3                    0.3                    0.2
# 69336                    0.4                    0.4                    0.2
#
# [69337 rows x 8155 columns]

# %%
train_data = train_data.drop(['customer_id'], axis=1)
train_data
# Out:
#        89118180927ffff_count  89118180d27ffff_count  891181820abffff_count  \
# 0                        0.2                    0.2                    0.2
# 1                       -1.0                   -1.0                   -1.0
# 2                       -1.0                   -1.0                   -1.0
# 3                        0.2                    0.2                    0.2
# 4                       -1.0                   -1.0                   -1.0
# ...                      ...                    ...                    ...
# 69332                   -1.0                   -1.0                   -1.0
# 69333                   -1.0                   -1.0                   -1.0
# 69334                   -1.0                   -1.0                   -1.0
# 69335                    0.2                    0.2                    0.2
# 69336                   -1.0                   -1.0                   -1.0
#
#        891181840a7ffff_count  891181844c3ffff_count  89118184c93ffff_count  \
# 0                        0.3                    0.3                    0.3
# 1                       -1.0                   -1.0                   -1.0
# 2                       -1.0                   -1.0                   -1.0
# 3                        0.3                    0.3                    0.3
# 4                       -1.0                   -1.0                   -1.0
# ...                      ...                    ...                    ...
# 69332                   -1.0                   -1.0                   -1.0
# 69333                   -1.0                   -1.0                   -1.0
# 69334                   -1.0                   -1.0                   -1.0
# 69335                    0.3                    0.3                    0.4
# 69336                   -1.0                   -1.0                   -1.0
#
#        891181854b7ffff_count  89118186067ffff_count  8911818610bffff_count  \
# 0                        0.2                    0.3                    0.3
# 1                       -1.0                   -1.0                   -1.0
# 2                       -1.0                   -1.0                   -1.0
# 3                        0.2                    0.3                    0.3
# 4                       -1.0                   -1.0                   -1.0
# ...                      ...                    ...                    ...
# 69332                   -1.0                   -1.0                   -1.0
# 69333                   -1.0                   -1.0                   -1.0
# 69334                   -1.0                   -1.0                   -1.0
# 69335                    0.2                    0.3                    0.3
# 69336                   -1.0                   -1.0                   -1.0
#
#        89118186173ffff_count  ...  8911aa7b6b3ffff_count  \
# 0                        0.3  ...                    0.7
# 1                       -1.0  ...                    0.7
# 2                       -1.0  ...                    0.3
# 3                        0.3  ...                    0.4
# 4                       -1.0  ...                    0.7
# ...                      ...  ...                    ...
# 69332                   -1.0  ...                    0.4
# 69333                   -1.0  ...                    0.4
# 69334                   -1.0  ...                    0.3
# 69335                    0.3  ...                    0.3
# 69336                   -1.0  ...                    0.4
#
#        8911aa7b6bbffff_count  8911aa7b6c3ffff_count  8911aa7b6c7ffff_count  \
# 0                        0.7                    0.5                    0.5
# 1                        0.7                    0.5                    0.5
# 2                        0.3                    0.3                    0.3
# 3                        0.4                    0.4                    0.4
# 4                        0.7                    0.5                    0.5
# ...                      ...                    ...                    ...
# 69332                    0.4                    0.4                    0.4
# 69333                    0.4                    0.4                    0.4
# 69334                    0.3                    0.3                    0.3
# 69335                    0.3                    0.3                    0.3
# 69336                    0.4                    0.4                    0.4
#
#        8911aa7b6cbffff_count  8911aa7b6cfffff_count  8911aa7b6d3ffff_count  \
# 0                        0.5                    0.5                    0.5
# 1                        0.5                    0.5                    0.5
# 2                        0.3                    0.3                    0.3
# 3                        0.4                    0.4                    0.4
# 4                        0.5                    0.5                    0.5
# ...                      ...                    ...                    ...
# 69332                    0.4                    0.4                    0.4
# 69333                    0.4                    0.4                    0.4
# 69334                    0.3                    0.3                    0.3
# 69335                    0.3                    0.3                    0.3
# 69336                    0.4                    0.4                    0.4
#
#        8911aa7b6d7ffff_count  8911aa7b6dbffff_count  8911aaccacfffff_count
# 0                        0.5                    0.5                    0.2
# 1                        0.5                    0.5                    0.2
# 2                        0.3                    0.3                    0.2
# 3                        0.4                    0.4                    0.2
# 4                        0.5                    0.5                    0.2
# ...                      ...                    ...                    ...
# 69332                    0.4                    0.4                    0.2
# 69333                    0.4                    0.4                    0.2
# 69334                    0.3                    0.3                    0.2
# 69335                    0.3                    0.3                    0.2
# 69336                    0.4                    0.4                    0.2
#
# [69337 rows x 8154 columns]

# %%
from iterstrat.ml_stratifiers import RepeatedMultilabelStratifiedKFold, MultilabelStratifiedKFold
from sklearn.metrics import log_loss

SEED = 42

train_scores=[]
val_scores = []

MBCE_train_scores=[]
MBCE_val_scores = []

rmskf = MultilabelStratifiedKFold(n_splits=7, shuffle=True, random_state=SEED)

for fold, (train_index, test_index) in enumerate(rmskf.split(train_data, target)):
        
    start = time.time()
    print(f'Fold: {fold}')
    print("TRAIN:", train_index, "TEST:", test_index)
    X_train, X_val = train_data.iloc[train_index], train_data.iloc[test_index]
    y_train, y_val = target.iloc[train_index], target.iloc[test_index]

    model = XGBClassifier(n_estimators=400,
                          depth=4,
                          nthread = -1,
                          sampling_method='gradient_based',
                          objective="binary:logistic", 
                          tree_method='gpu_hist',
                          learning_rate = 0.1,
                          reg_lambda = 100
                         )
   
    model.fit(X_train, y_train,eval_set=[(X_val, y_val)],
          verbose=5,early_stopping_rounds=5)
    joblib.dump(model, f'model_{SEED}_{fold}.pkl')
  
            
    train_preds = model.predict_proba(X_train)
    valid_preds = model.predict_proba(X_val) 
            
    train_score = log_loss(y_train, train_preds)
    val_score = log_loss(y_val, valid_preds)
    
    print(f'Результат log_loss на трейн: {train_score}')
    print(f'Результат log_loss на тесте: {val_score}')
    print('----------->')
    print(f'Результат MBCE на трейн: {mean_binary_cross_entropy(train_preds,y_train)}')
    print(f'Результат MBCE на тесте: {mean_binary_cross_entropy(valid_preds,y_val)}')
    
            
    train_scores.append(train_score)
    val_scores.append(val_score)
            
    MBCE_train_scores.append(mean_binary_cross_entropy(train_preds,y_train))
    MBCE_val_scores.append(mean_binary_cross_entropy(valid_preds,y_val))

    end = time.time()
    print('fold:', fold, 'time:', round((end-start)/60, 3))
    print()
    print()
# Out:
# Fold: 0
# TRAIN: [    0     1     2 ... 69333 69334 69336] TEST: [    4     8    13 ... 69321 69331 69335]
# [0]	validation_0-logloss:0.11772
# [5]	validation_0-logloss:0.07212
# [10]	validation_0-logloss:0.04560
# [15]	validation_0-logloss:0.02991
# [20]	validation_0-logloss:0.02054
# [25]	validation_0-logloss:0.01492
# [30]	validation_0-logloss:0.01151
# [35]	validation_0-logloss:0.00943
# [40]	validation_0-logloss:0.00813
# [45]	validation_0-logloss:0.00731
# [50]	validation_0-logloss:0.00677
# [55]	validation_0-logloss:0.00641
# [60]	validation_0-logloss:0.00616
# [65]	validation_0-logloss:0.00597
# [70]	validation_0-logloss:0.00584
# [75]	validation_0-logloss:0.00574
# [80]	validation_0-logloss:0.00566
# [85]	validation_0-logloss:0.00560
# [90]	validation_0-logloss:0.00555
# [95]	validation_0-logloss:0.00551
# [100]	validation_0-logloss:0.00547
# [105]	validation_0-logloss:0.00544
# [110]	validation_0-logloss:0.00542
# [115]	validation_0-logloss:0.00540
# [120]	validation_0-logloss:0.00538
# [125]	validation_0-logloss:0.00537
# [130]	validation_0-logloss:0.00536
# [135]	validation_0-logloss:0.00534
# [140]	validation_0-logloss:0.00534
# [145]	validation_0-logloss:0.00533
# [150]	validation_0-logloss:0.00532
# [155]	validation_0-logloss:0.00531
# [160]	validation_0-logloss:0.00531
# [165]	validation_0-logloss:0.00530
# [170]	validation_0-logloss:0.00530
# [175]	validation_0-logloss:0.00529
# [180]	validation_0-logloss:0.00529
# [185]	validation_0-logloss:0.00529
# [190]	validation_0-logloss:0.00528
# [195]	validation_0-logloss:0.00528
# [200]	validation_0-logloss:0.00528
# [205]	validation_0-logloss:0.00528
# [210]	validation_0-logloss:0.00528
# [215]	validation_0-logloss:0.00528
# [220]	validation_0-logloss:0.00527
# [225]	validation_0-logloss:0.00527
# [230]	validation_0-logloss:0.00527
# [235]	validation_0-logloss:0.00527
# [240]	validation_0-logloss:0.00527
# [245]	validation_0-logloss:0.00527
# [250]	validation_0-logloss:0.00527
# [255]	validation_0-logloss:0.00527
# [259]	validation_0-logloss:0.00527
# Результат log_loss на трейн: 5.9193440447957215
# Результат log_loss на тесте: 8.583603952463523
# ----------->
# Результат MBCE на трейн: 5.4717894996884135
# Результат MBCE на тесте: 8.73522661408979
# fold: 0 time: 439.591
#
#
# Fold: 1
# TRAIN: [    0     1     2 ... 69333 69335 69336] TEST: [    9    24    27 ... 69326 69327 69334]
# [0]	validation_0-logloss:0.11774
# [5]	validation_0-logloss:0.07214
# [10]	validation_0-logloss:0.04562
# [15]	validation_0-logloss:0.02994
# [20]	validation_0-logloss:0.02058
# [25]	validation_0-logloss:0.01495
# [30]	validation_0-logloss:0.01155
# [35]	validation_0-logloss:0.00947
# [40]	validation_0-logloss:0.00818
# [45]	validation_0-logloss:0.00736
# [50]	validation_0-logloss:0.00682
# [55]	validation_0-logloss:0.00646
# [60]	validation_0-logloss:0.00621
# [65]	validation_0-logloss:0.00603
# [70]	validation_0-logloss:0.00590
# [75]	validation_0-logloss:0.00580
# [80]	validation_0-logloss:0.00572
# [85]	validation_0-logloss:0.00566
# [90]	validation_0-logloss:0.00561
# [95]	validation_0-logloss:0.00557
# [100]	validation_0-logloss:0.00553
# [105]	validation_0-logloss:0.00551
# [110]	validation_0-logloss:0.00548
# [115]	validation_0-logloss:0.00546
# [120]	validation_0-logloss:0.00545
# [125]	validation_0-logloss:0.00543
# [130]	validation_0-logloss:0.00542
# [135]	validation_0-logloss:0.00541
# [140]	validation_0-logloss:0.00540
# [145]	validation_0-logloss:0.00539
# [150]	validation_0-logloss:0.00539
# [155]	validation_0-logloss:0.00538
# [160]	validation_0-logloss:0.00537
# [165]	validation_0-logloss:0.00537
# [170]	validation_0-logloss:0.00537
# [175]	validation_0-logloss:0.00536
# [180]	validation_0-logloss:0.00536
# [185]	validation_0-logloss:0.00536
# [190]	validation_0-logloss:0.00535
# [195]	validation_0-logloss:0.00535
# [200]	validation_0-logloss:0.00535
# [205]	validation_0-logloss:0.00535
# [210]	validation_0-logloss:0.00535
# [215]	validation_0-logloss:0.00535
# [220]	validation_0-logloss:0.00534
# [225]	validation_0-logloss:0.00534
# [230]	validation_0-logloss:0.00534
# [235]	validation_0-logloss:0.00534
# [240]	validation_0-logloss:0.00534
# [245]	validation_0-logloss:0.00534
# [247]	validation_0-logloss:0.00534
# Результат log_loss на трейн: 5.955869928748112
# Результат log_loss на тесте: 8.713777764915195
# ----------->
# Результат MBCE на трейн: 5.527648775346034
# Результат MBCE на тесте: 8.852509356199318
# fold: 1 time: 420.002
#
#
# Fold: 2
# TRAIN: [    3     4     5 ... 69333 69334 69335] TEST: [    0     1     2 ... 69309 69314 69336]
# [0]	validation_0-logloss:0.11774
# [5]	validation_0-logloss:0.07215
# [10]	validation_0-logloss:0.04562
# [15]	validation_0-logloss:0.02994
# [20]	validation_0-logloss:0.02058
# [25]	validation_0-logloss:0.01495
# [30]	validation_0-logloss:0.01155
# [35]	validation_0-logloss:0.00947
# [40]	validation_0-logloss:0.00817
# [45]	validation_0-logloss:0.00735
# [50]	validation_0-logloss:0.00681
# [55]	validation_0-logloss:0.00645
# [60]	validation_0-logloss:0.00620
# [65]	validation_0-logloss:0.00602
# [70]	validation_0-logloss:0.00589
# [75]	validation_0-logloss:0.00579
# [80]	validation_0-logloss:0.00571
# [85]	validation_0-logloss:0.00565
# [90]	validation_0-logloss:0.00560
# [95]	validation_0-logloss:0.00556
# [100]	validation_0-logloss:0.00552
# [105]	validation_0-logloss:0.00550
# [110]	validation_0-logloss:0.00547
# [115]	validation_0-logloss:0.00545
# [120]	validation_0-logloss:0.00543
# [125]	validation_0-logloss:0.00542
# [130]	validation_0-logloss:0.00541
# [135]	validation_0-logloss:0.00540
# [140]	validation_0-logloss:0.00539
# [145]	validation_0-logloss:0.00538
# [150]	validation_0-logloss:0.00537
# [155]	validation_0-logloss:0.00536
# [160]	validation_0-logloss:0.00536
# [165]	validation_0-logloss:0.00535
# [170]	validation_0-logloss:0.00535
# [175]	validation_0-logloss:0.00535
# [180]	validation_0-logloss:0.00534
# [185]	validation_0-logloss:0.00534
# [190]	validation_0-logloss:0.00534
# [195]	validation_0-logloss:0.00533
# [200]	validation_0-logloss:0.00533
# [205]	validation_0-logloss:0.00533
# [210]	validation_0-logloss:0.00533
# [215]	validation_0-logloss:0.00533
# [220]	validation_0-logloss:0.00533
# [225]	validation_0-logloss:0.00533
# [230]	validation_0-logloss:0.00533
# [235]	validation_0-logloss:0.00533
# [240]	validation_0-logloss:0.00533
# [243]	validation_0-logloss:0.00533
# Результат log_loss на трейн: 5.985316541517654
# Результат log_loss на тесте: 8.679911839035125
# ----------->
# Результат MBCE на трейн: 5.563983665378282
# Результат MBCE на тесте: 8.82372145853905
# fold: 2 time: 409.081
#
#
# Fold: 3
# TRAIN: [    0     1     2 ... 69334 69335 69336] TEST: [    5    15    19 ... 69319 69320 69323]
# [0]	validation_0-logloss:0.11770
# [5]	validation_0-logloss:0.07210
# [10]	validation_0-logloss:0.04558
# [15]	validation_0-logloss:0.02989
# [20]	validation_0-logloss:0.02052
# [25]	validation_0-logloss:0.01490
# [30]	validation_0-logloss:0.01149
# [35]	validation_0-logloss:0.00940
# [40]	validation_0-logloss:0.00811
# [45]	validation_0-logloss:0.00728
# [50]	validation_0-logloss:0.00674
# [55]	validation_0-logloss:0.00638
# [60]	validation_0-logloss:0.00613
# [65]	validation_0-logloss:0.00595
# [70]	validation_0-logloss:0.00581
# [75]	validation_0-logloss:0.00571
# [80]	validation_0-logloss:0.00563
# [85]	validation_0-logloss:0.00557
# [90]	validation_0-logloss:0.00551
# [95]	validation_0-logloss:0.00547
# [100]	validation_0-logloss:0.00544
# [105]	validation_0-logloss:0.00541
# [110]	validation_0-logloss:0.00539
# [115]	validation_0-logloss:0.00537
# [120]	validation_0-logloss:0.00535
# [125]	validation_0-logloss:0.00533
# [130]	validation_0-logloss:0.00532
# [135]	validation_0-logloss:0.00531
# [140]	validation_0-logloss:0.00530
# [145]	validation_0-logloss:0.00529
# [150]	validation_0-logloss:0.00529
# [155]	validation_0-logloss:0.00528
# [160]	validation_0-logloss:0.00527
# [165]	validation_0-logloss:0.00527
# [170]	validation_0-logloss:0.00526
# [175]	validation_0-logloss:0.00526
# [180]	validation_0-logloss:0.00526
# [185]	validation_0-logloss:0.00525
# [190]	validation_0-logloss:0.00525
# [195]	validation_0-logloss:0.00525
# [200]	validation_0-logloss:0.00525
# [205]	validation_0-logloss:0.00524
# [210]	validation_0-logloss:0.00524
# [215]	validation_0-logloss:0.00524
# [220]	validation_0-logloss:0.00524
# [225]	validation_0-logloss:0.00524
# [230]	validation_0-logloss:0.00524
# [235]	validation_0-logloss:0.00524
# [240]	validation_0-logloss:0.00524
# [245]	validation_0-logloss:0.00524
# [250]	validation_0-logloss:0.00524
# Результат log_loss на трейн: 5.971244309237959
# Результат log_loss на тесте: 8.516612491360776
# ----------->
# Результат MBCE на трейн: 5.534085449920663
# Результат MBCE на тесте: 8.681052314334346
# fold: 3 time: 422.072
#
#
# Fold: 4
# TRAIN: [    0     1     2 ... 69334 69335 69336] TEST: [   10    22    30 ... 69328 69329 69332]
# [0]	validation_0-logloss:0.11769
# [5]	validation_0-logloss:0.07209
# [10]	validation_0-logloss:0.04557
# [15]	validation_0-logloss:0.02988
# [20]	validation_0-logloss:0.02051
# [25]	validation_0-logloss:0.01488
# [30]	validation_0-logloss:0.01147
# [35]	validation_0-logloss:0.00939
# [40]	validation_0-logloss:0.00810
# [45]	validation_0-logloss:0.00727
# [50]	validation_0-logloss:0.00674
# [55]	validation_0-logloss:0.00637
# [60]	validation_0-logloss:0.00612
# [65]	validation_0-logloss:0.00594
# [70]	validation_0-logloss:0.00580
# [75]	validation_0-logloss:0.00570
# [80]	validation_0-logloss:0.00562
# [85]	validation_0-logloss:0.00556
# [90]	validation_0-logloss:0.00551
# [95]	validation_0-logloss:0.00547
# [100]	validation_0-logloss:0.00544
# [105]	validation_0-logloss:0.00541
# [110]	validation_0-logloss:0.00539
# [115]	validation_0-logloss:0.00537
# [120]	validation_0-logloss:0.00535
# [125]	validation_0-logloss:0.00533
# [130]	validation_0-logloss:0.00532
# [135]	validation_0-logloss:0.00531
# [140]	validation_0-logloss:0.00530
# [145]	validation_0-logloss:0.00529
# [150]	validation_0-logloss:0.00528
# [155]	validation_0-logloss:0.00528
# [160]	validation_0-logloss:0.00527
# [165]	validation_0-logloss:0.00527
# [170]	validation_0-logloss:0.00526
# [175]	validation_0-logloss:0.00526
# [180]	validation_0-logloss:0.00525
# [185]	validation_0-logloss:0.00525
# [190]	validation_0-logloss:0.00525
# [195]	validation_0-logloss:0.00525
# [200]	validation_0-logloss:0.00525
# [205]	validation_0-logloss:0.00524
# [210]	validation_0-logloss:0.00524
# [215]	validation_0-logloss:0.00524
# [220]	validation_0-logloss:0.00524
# [225]	validation_0-logloss:0.00524
# [230]	validation_0-logloss:0.00524
# [235]	validation_0-logloss:0.00524
# [240]	validation_0-logloss:0.00524
# [245]	validation_0-logloss:0.00524
# [250]	validation_0-logloss:0.00524
# [255]	validation_0-logloss:0.00524
# [260]	validation_0-logloss:0.00524
# Результат log_loss на трейн: 5.929861049108755
# Результат log_loss на тесте: 8.496870573950925
# ----------->
# Результат MBCE на трейн: 5.474782045898213
# Результат MBCE на тесте: 8.678532315122403
# fold: 4 time: 439.894
#
#
# Fold: 5
# TRAIN: [    0     1     2 ... 69334 69335 69336] TEST: [   17    18    20 ... 69318 69330 69333]
# [0]	validation_0-logloss:0.11773
# [5]	validation_0-logloss:0.07214
# [10]	validation_0-logloss:0.04562
# [15]	validation_0-logloss:0.02993
# [20]	validation_0-logloss:0.02057
# [25]	validation_0-logloss:0.01495
# [30]	validation_0-logloss:0.01155
# [35]	validation_0-logloss:0.00947
# [40]	validation_0-logloss:0.00818
# [45]	validation_0-logloss:0.00736
# [50]	validation_0-logloss:0.00682
# [55]	validation_0-logloss:0.00646
# [60]	validation_0-logloss:0.00622
# [65]	validation_0-logloss:0.00604
# [70]	validation_0-logloss:0.00590
# [75]	validation_0-logloss:0.00580
# [80]	validation_0-logloss:0.00573
# [85]	validation_0-logloss:0.00566
# [90]	validation_0-logloss:0.00561
# [95]	validation_0-logloss:0.00557
# [100]	validation_0-logloss:0.00554
# [105]	validation_0-logloss:0.00551
# [110]	validation_0-logloss:0.00549
# [115]	validation_0-logloss:0.00547
# [120]	validation_0-logloss:0.00545
# [125]	validation_0-logloss:0.00544
# [130]	validation_0-logloss:0.00543
# [135]	validation_0-logloss:0.00542
# [140]	validation_0-logloss:0.00541
# [145]	validation_0-logloss:0.00540
# [150]	validation_0-logloss:0.00539
# [155]	validation_0-logloss:0.00538
# [160]	validation_0-logloss:0.00538
# [165]	validation_0-logloss:0.00537
# [170]	validation_0-logloss:0.00537
# [175]	validation_0-logloss:0.00537
# [180]	validation_0-logloss:0.00536
# [185]	validation_0-logloss:0.00536
# [190]	validation_0-logloss:0.00536
# [195]	validation_0-logloss:0.00536
# [200]	validation_0-logloss:0.00535
# [205]	validation_0-logloss:0.00535
# [210]	validation_0-logloss:0.00535
# [215]	validation_0-logloss:0.00535
# [220]	validation_0-logloss:0.00535
# [225]	validation_0-logloss:0.00535
# [230]	validation_0-logloss:0.00535
# [235]	validation_0-logloss:0.00535
# [240]	validation_0-logloss:0.00535
# [245]	validation_0-logloss:0.00535
# [250]	validation_0-logloss:0.00535
# [255]	validation_0-logloss:0.00535
# [257]	validation_0-logloss:0.00535
# Результат log_loss на трейн: 5.9135138783391765
# Результат log_loss на тесте: 8.709616457008503
# ----------->
# Результат MBCE на трейн: 5.470830851032641
# Результат MBCE на тесте: 8.858411587417853
# fold: 5 time: 435.825
#
#
# Fold: 6
# TRAIN: [    0     1     2 ... 69334 69335 69336] TEST: [    3     6    14 ... 69310 69322 69324]
# [0]	validation_0-logloss:0.11774
# [5]	validation_0-logloss:0.07215
# [10]	validation_0-logloss:0.04563
# [15]	validation_0-logloss:0.02995
# [20]	validation_0-logloss:0.02059
# [25]	validation_0-logloss:0.01497
# [30]	validation_0-logloss:0.01157
# [35]	validation_0-logloss:0.00948
# [40]	validation_0-logloss:0.00819
# [45]	validation_0-logloss:0.00737
# [50]	validation_0-logloss:0.00684
# [55]	validation_0-logloss:0.00648
# [60]	validation_0-logloss:0.00622
# [65]	validation_0-logloss:0.00604
# [70]	validation_0-logloss:0.00591
# [75]	validation_0-logloss:0.00581
# [80]	validation_0-logloss:0.00573
# [85]	validation_0-logloss:0.00567
# [90]	validation_0-logloss:0.00562
# [95]	validation_0-logloss:0.00558
# [100]	validation_0-logloss:0.00555
# [105]	validation_0-logloss:0.00552
# [110]	validation_0-logloss:0.00550
# [115]	validation_0-logloss:0.00548
# [120]	validation_0-logloss:0.00547
# [125]	validation_0-logloss:0.00545
# [130]	validation_0-logloss:0.00544
# [135]	validation_0-logloss:0.00543
# [140]	validation_0-logloss:0.00542
# [145]	validation_0-logloss:0.00541
# [150]	validation_0-logloss:0.00540
# [155]	validation_0-logloss:0.00540
# [160]	validation_0-logloss:0.00539
# [165]	validation_0-logloss:0.00539
# [170]	validation_0-logloss:0.00538
# [175]	validation_0-logloss:0.00538
# [180]	validation_0-logloss:0.00538
# [185]	validation_0-logloss:0.00537
# [190]	validation_0-logloss:0.00537
# [195]	validation_0-logloss:0.00537
# [200]	validation_0-logloss:0.00537
# [205]	validation_0-logloss:0.00537
# [210]	validation_0-logloss:0.00537
# [215]	validation_0-logloss:0.00537
# [220]	validation_0-logloss:0.00536
# [225]	validation_0-logloss:0.00536
# [230]	validation_0-logloss:0.00536
# [235]	validation_0-logloss:0.00536
# [239]	validation_0-logloss:0.00536
# Результат log_loss на трейн: 5.992210810278976
# Результат log_loss на тесте: 8.73704786985779
# ----------->
# Результат MBCE на трейн: 5.574535789191192
# Результат MBCE на тесте: 8.88657791914882
# fold: 6 time: 404.184

# %%
print(f'MBCE на валидации: {sum(MBCE_val_scores)/len(MBCE_val_scores)}')
# Out:
# MBCE на валидации: 8.788004509264512
